# %%
import os
from experiments.MONK.common import run_monk_selection

SEEDS = [42]
TOP_K = 10

CONFIG_MONK1 = "experiments/MONK/configs/monk1.yaml"
OUT_MONK1 = "experiments/MONK/results/monk1"

os.makedirs(OUT_MONK1, exist_ok=True)

print("\n==============================")
print("Running MONK-1 model selection")
print("==============================")

out_monk1 = run_monk_selection(
    config_path=CONFIG_MONK1,
    out_dir=OUT_MONK1,
    seeds=SEEDS,
    top_k=TOP_K,
)

print("MONK-1 DONE")
print("Best score:", out_monk1["best_score"])
# Out:
# ==============================
# Running MONK-1 model selection
# ==============================
# [grid:holdout] 1/1296 config_id=f6546afc5813 seed=42
# [grid:holdout] 2/1296 config_id=28254568b15d seed=42
# [grid:holdout] 3/1296 config_id=c3d171a89935 seed=42
# [grid:holdout] 4/1296 config_id=445dd0a80a63 seed=42
# [grid:holdout] 5/1296 config_id=7c729cdc112c seed=42
# [grid:holdout] 6/1296 config_id=d17cfcbd21c8 seed=42
# [grid:holdout] 7/1296 config_id=7457af011561 seed=42
# [grid:holdout] 8/1296 config_id=601a6f952ade seed=42
# [grid:holdout] 9/1296 config_id=0020f552137f seed=42
# [grid:holdout] 10/1296 config_id=5ccf3799dce0 seed=42
# [grid:holdout] 11/1296 config_id=9cd58eb5555a seed=42
# [grid:holdout] 12/1296 config_id=c5e18cb58c0c seed=42
# [grid:holdout] 13/1296 config_id=ca9ad25cc074 seed=42
# [grid:holdout] 14/1296 config_id=5c3062177729 seed=42
# [grid:holdout] 15/1296 config_id=e877430363a9 seed=42
# [grid:holdout] 16/1296 config_id=833a6bda4e2b seed=42
# [grid:holdout] 17/1296 config_id=9afcb4f00c21 seed=42
# [grid:holdout] 18/1296 config_id=cc71c844adf4 seed=42
# [grid:holdout] 19/1296 config_id=3ff08271a92f seed=42
# [grid:holdout] 20/1296 config_id=f286fff6724a seed=42
# [grid:holdout] 21/1296 config_id=b15a0a581bbb seed=42
# [grid:holdout] 22/1296 config_id=d5e025fa9232 seed=42
# [grid:holdout] 23/1296 config_id=3b9883e350fc seed=42
# [grid:holdout] 24/1296 config_id=f7456a1c72cf seed=42
# [grid:holdout] 25/1296 config_id=d69974ed7c81 seed=42
# [grid:holdout] 26/1296 config_id=17bdb867986e seed=42
# [grid:holdout] 27/1296 config_id=7637b94cb848 seed=42
# [grid:holdout] 28/1296 config_id=69b502eba1ef seed=42
# [grid:holdout] 29/1296 config_id=5ff8d8b5ce3b seed=42
# [grid:holdout] 30/1296 config_id=23326f560b5b seed=42
# [grid:holdout] 31/1296 config_id=f3f6fc70e5c4 seed=42
# [grid:holdout] 32/1296 config_id=81f80a2c64f3 seed=42
# [grid:holdout] 33/1296 config_id=f170d2d554b0 seed=42
# [grid:holdout] 34/1296 config_id=452766e6cc8a seed=42
# [grid:holdout] 35/1296 config_id=7a25f0740676 seed=42
# [grid:holdout] 36/1296 config_id=73bb66b2af67 seed=42
# [grid:holdout] 37/1296 config_id=ee1cede61b9d seed=42
# [grid:holdout] 38/1296 config_id=27c3fc50d95d seed=42
# [grid:holdout] 39/1296 config_id=b45bc6a0bddf seed=42
# [grid:holdout] 40/1296 config_id=f308af409aa5 seed=42
# [grid:holdout] 41/1296 config_id=e77fa3f749f9 seed=42
# [grid:holdout] 42/1296 config_id=d441015c2316 seed=42
# [grid:holdout] 43/1296 config_id=cab476986005 seed=42
# [grid:holdout] 44/1296 config_id=0e4c476cce65 seed=42
# [grid:holdout] 45/1296 config_id=f1ff96b70290 seed=42
# [grid:holdout] 46/1296 config_id=8e82dc5e240f seed=42
# [grid:holdout] 47/1296 config_id=d198d66589e4 seed=42
# [grid:holdout] 48/1296 config_id=543155bad756 seed=42
# [grid:holdout] 49/1296 config_id=b2c33efbc357 seed=42
# [grid:holdout] 50/1296 config_id=1cd81bf3f34b seed=42
# [grid:holdout] 51/1296 config_id=172401fc618b seed=42
# [grid:holdout] 52/1296 config_id=5fb298c53a71 seed=42
# [grid:holdout] 53/1296 config_id=6fd2479c4acc seed=42
# [grid:holdout] 54/1296 config_id=10f7d01c8b3d seed=42
# [grid:holdout] 55/1296 config_id=4e6cf7b66ef5 seed=42
# [grid:holdout] 56/1296 config_id=5b6a8df9f2ad seed=42
# [grid:holdout] 57/1296 config_id=944d7ea1fa0f seed=42
# [grid:holdout] 58/1296 config_id=9d84aaf7c53b seed=42
# [grid:holdout] 59/1296 config_id=8dbed693e6cf seed=42
# [grid:holdout] 60/1296 config_id=f567a9f3e135 seed=42
# [grid:holdout] 61/1296 config_id=d3653e704d5b seed=42
# [grid:holdout] 62/1296 config_id=ed3b8d7c8f26 seed=42
# [grid:holdout] 63/1296 config_id=da6a8f54bb08 seed=42
# [grid:holdout] 64/1296 config_id=96e4164ccad7 seed=42
# [grid:holdout] 65/1296 config_id=671190210acf seed=42
# [grid:holdout] 66/1296 config_id=f23e4266edc7 seed=42
# [grid:holdout] 67/1296 config_id=b695cf4ce9a4 seed=42
# [grid:holdout] 68/1296 config_id=427cd2bac6ab seed=42
# [grid:holdout] 69/1296 config_id=2862fd7cf813 seed=42
# [grid:holdout] 70/1296 config_id=873fb5115252 seed=42
# [grid:holdout] 71/1296 config_id=d0ebc5b82913 seed=42
# [grid:holdout] 72/1296 config_id=8c51d891a52d seed=42
# [grid:holdout] 73/1296 config_id=4f4cd795ef09 seed=42
# [grid:holdout] 74/1296 config_id=56ff3a10a88c seed=42
# [grid:holdout] 75/1296 config_id=c5b229a8e905 seed=42
# [grid:holdout] 76/1296 config_id=b7c89d10e6a7 seed=42
# [grid:holdout] 77/1296 config_id=d574423c484b seed=42
# [grid:holdout] 78/1296 config_id=fa6fbb8f37c6 seed=42
# [grid:holdout] 79/1296 config_id=eb30120e4595 seed=42
# [grid:holdout] 80/1296 config_id=b467076716f7 seed=42
# [grid:holdout] 81/1296 config_id=f8310b8485ff seed=42
# [grid:holdout] 82/1296 config_id=fa0077ef3f8f seed=42
# [grid:holdout] 83/1296 config_id=a6ce2346f85c seed=42
# [grid:holdout] 84/1296 config_id=77adf8b317fc seed=42
# [grid:holdout] 85/1296 config_id=dbcd18af9bb6 seed=42
# [grid:holdout] 86/1296 config_id=93e23ed72a41 seed=42
# [grid:holdout] 87/1296 config_id=83a3012aa9a4 seed=42
# [grid:holdout] 88/1296 config_id=3d3ef266bf5b seed=42
# [grid:holdout] 89/1296 config_id=1c2f29077df6 seed=42
# [grid:holdout] 90/1296 config_id=67194a77e2b9 seed=42
# [grid:holdout] 91/1296 config_id=8c4be241ab1a seed=42
# [grid:holdout] 92/1296 config_id=ddf0b71cd13f seed=42
# [grid:holdout] 93/1296 config_id=4ec7a72b330f seed=42
# [grid:holdout] 94/1296 config_id=6630edac0de3 seed=42
# [grid:holdout] 95/1296 config_id=6a9f7c691b39 seed=42
# [grid:holdout] 96/1296 config_id=0d51c26deebc seed=42
# [grid:holdout] 97/1296 config_id=e94d4833a3c2 seed=42
# [grid:holdout] 98/1296 config_id=aa638b1800f5 seed=42
# [grid:holdout] 99/1296 config_id=53e093bea42f seed=42
# [grid:holdout] 100/1296 config_id=0d1be3c2f230 seed=42
# [grid:holdout] 101/1296 config_id=f27491327a79 seed=42
# [grid:holdout] 102/1296 config_id=f262621b2e1a seed=42
# [grid:holdout] 103/1296 config_id=978d16fb32d8 seed=42
# [grid:holdout] 104/1296 config_id=9916e8fae407 seed=42
# [grid:holdout] 105/1296 config_id=3280b5d9e6aa seed=42
# [grid:holdout] 106/1296 config_id=1025e8b4eddd seed=42
# [grid:holdout] 107/1296 config_id=6ded27742c77 seed=42
# [grid:holdout] 108/1296 config_id=e5b45b62cb12 seed=42
# [grid:holdout] 109/1296 config_id=fcebe26414b4 seed=42
# [grid:holdout] 110/1296 config_id=195520cb6d48 seed=42
# [grid:holdout] 111/1296 config_id=5a7d6f987ce5 seed=42
# [grid:holdout] 112/1296 config_id=b82cf102400f seed=42
# [grid:holdout] 113/1296 config_id=f7be34cfd79f seed=42
# [grid:holdout] 114/1296 config_id=177240a95fc3 seed=42
# [grid:holdout] 115/1296 config_id=d58f44e6e8c2 seed=42
# [grid:holdout] 116/1296 config_id=f6766705ea48 seed=42
# [grid:holdout] 117/1296 config_id=fa5644fb5c2a seed=42
# [grid:holdout] 118/1296 config_id=1dff49e64fc5 seed=42
# [grid:holdout] 119/1296 config_id=cc85d0c0cc69 seed=42
# [grid:holdout] 120/1296 config_id=e07df731852b seed=42
# [grid:holdout] 121/1296 config_id=69b324a5cad7 seed=42
# [grid:holdout] 122/1296 config_id=fddd62f8c9f2 seed=42
# [grid:holdout] 123/1296 config_id=e3d929437e04 seed=42
# [grid:holdout] 124/1296 config_id=91124c763905 seed=42
# [grid:holdout] 125/1296 config_id=f69d724af436 seed=42
# [grid:holdout] 126/1296 config_id=daa6a52c249d seed=42
# [grid:holdout] 127/1296 config_id=f691395cbbe7 seed=42
# [grid:holdout] 128/1296 config_id=24da45c82309 seed=42
# [grid:holdout] 129/1296 config_id=18b308dfe358 seed=42
# [grid:holdout] 130/1296 config_id=9a7f59e8aecf seed=42
# [grid:holdout] 131/1296 config_id=68ec5a9f085c seed=42
# [grid:holdout] 132/1296 config_id=4bbbd5cb35d8 seed=42
# [grid:holdout] 133/1296 config_id=f10904777536 seed=42
# [grid:holdout] 134/1296 config_id=0ab269a8e03e seed=42
# [grid:holdout] 135/1296 config_id=83abea4fea9d seed=42
# [grid:holdout] 136/1296 config_id=04bfa922f544 seed=42
# [grid:holdout] 137/1296 config_id=e55230571e51 seed=42
# [grid:holdout] 138/1296 config_id=e4c18ca1253c seed=42
# [grid:holdout] 139/1296 config_id=f8f1ecb2fad9 seed=42
# [grid:holdout] 140/1296 config_id=70c6a6e6acb0 seed=42
# [grid:holdout] 141/1296 config_id=786f7ae18ccd seed=42
# [grid:holdout] 142/1296 config_id=01b7ebebaefe seed=42
# [grid:holdout] 143/1296 config_id=710471039804 seed=42
# [grid:holdout] 144/1296 config_id=bf56087f8ce7 seed=42
# [grid:holdout] 145/1296 config_id=3121ca1a38e1 seed=42
# [grid:holdout] 146/1296 config_id=0027171f78db seed=42
# [grid:holdout] 147/1296 config_id=0488c9f53294 seed=42
# [grid:holdout] 148/1296 config_id=74396cbd5a81 seed=42
# [grid:holdout] 149/1296 config_id=a4ce55b30e0e seed=42
# [grid:holdout] 150/1296 config_id=c90eec20ec03 seed=42
# [grid:holdout] 151/1296 config_id=91fb2f3a7339 seed=42
# [grid:holdout] 152/1296 config_id=93f6329ca617 seed=42
# [grid:holdout] 153/1296 config_id=51964088f3a0 seed=42
# [grid:holdout] 154/1296 config_id=251998a5f88d seed=42
# [grid:holdout] 155/1296 config_id=fb83ac296b50 seed=42
# [grid:holdout] 156/1296 config_id=bda3bbd8e60e seed=42
# [grid:holdout] 157/1296 config_id=2e4dcfa35d81 seed=42
# [grid:holdout] 158/1296 config_id=47160da553d3 seed=42
# [grid:holdout] 159/1296 config_id=31103048c6e3 seed=42
# [grid:holdout] 160/1296 config_id=62120bde283f seed=42
# [grid:holdout] 161/1296 config_id=47bba093b4ca seed=42
# [grid:holdout] 162/1296 config_id=548878f4ee7b seed=42
# [grid:holdout] 163/1296 config_id=15a19c1dbef1 seed=42
# [grid:holdout] 164/1296 config_id=d46ef3f1c806 seed=42
# [grid:holdout] 165/1296 config_id=d5d7efa0fd7f seed=42
# [grid:holdout] 166/1296 config_id=90eea0b7de7b seed=42
# [grid:holdout] 167/1296 config_id=e19e73614193 seed=42
# [grid:holdout] 168/1296 config_id=77ee787b9958 seed=42
# [grid:holdout] 169/1296 config_id=f56a87d7420c seed=42
# [grid:holdout] 170/1296 config_id=6715441fd1db seed=42
# [grid:holdout] 171/1296 config_id=b2afa668f991 seed=42
# [grid:holdout] 172/1296 config_id=73c42e638bae seed=42
# [grid:holdout] 173/1296 config_id=dc077579ff77 seed=42
# [grid:holdout] 174/1296 config_id=185918455ba7 seed=42
# [grid:holdout] 175/1296 config_id=d6f69235a52b seed=42
# [grid:holdout] 176/1296 config_id=1b6d692e9382 seed=42
# [grid:holdout] 177/1296 config_id=5757f5242cfc seed=42
# [grid:holdout] 178/1296 config_id=2666d15b2f35 seed=42
# [grid:holdout] 179/1296 config_id=8497aeb9257c seed=42
# [grid:holdout] 180/1296 config_id=629fc819271f seed=42
# [grid:holdout] 181/1296 config_id=7dbeb816818c seed=42
# [grid:holdout] 182/1296 config_id=ba2135092677 seed=42
# [grid:holdout] 183/1296 config_id=8e9ebaec3fd8 seed=42
# [grid:holdout] 184/1296 config_id=11b4cad04496 seed=42
# [grid:holdout] 185/1296 config_id=4c510d0244e8 seed=42
# [grid:holdout] 186/1296 config_id=2c5f17467c32 seed=42
# [grid:holdout] 187/1296 config_id=7c3b2e4e5934 seed=42
# [grid:holdout] 188/1296 config_id=16e452566a0b seed=42
# [grid:holdout] 189/1296 config_id=d2a070172900 seed=42
# [grid:holdout] 190/1296 config_id=8fc0cffc4e2d seed=42
# [grid:holdout] 191/1296 config_id=9ca8a9e4a020 seed=42
# [grid:holdout] 192/1296 config_id=1661da1ddd07 seed=42
# [grid:holdout] 193/1296 config_id=4446bd297d60 seed=42
# [grid:holdout] 194/1296 config_id=1a4564e177fb seed=42
# [grid:holdout] 195/1296 config_id=d168693161cc seed=42
# [grid:holdout] 196/1296 config_id=dcec672935ff seed=42
# [grid:holdout] 197/1296 config_id=2b27aaf2310b seed=42
# [grid:holdout] 198/1296 config_id=460966ba2167 seed=42
# [grid:holdout] 199/1296 config_id=0e9f5c1e5265 seed=42
# [grid:holdout] 200/1296 config_id=fd3bf7c79d50 seed=42
# [grid:holdout] 201/1296 config_id=8bf267e05443 seed=42
# [grid:holdout] 202/1296 config_id=27ffecf5d349 seed=42
# [grid:holdout] 203/1296 config_id=ac603336b8df seed=42
# [grid:holdout] 204/1296 config_id=527fc5c41fca seed=42
# [grid:holdout] 205/1296 config_id=ee2262acbba5 seed=42
# [grid:holdout] 206/1296 config_id=fe3814e30c9b seed=42
# [grid:holdout] 207/1296 config_id=08518f41a6bf seed=42
# [grid:holdout] 208/1296 config_id=9b01145724f2 seed=42
# [grid:holdout] 209/1296 config_id=31b5bbf247a9 seed=42
# [grid:holdout] 210/1296 config_id=759cb59cd769 seed=42
# [grid:holdout] 211/1296 config_id=cf937a39b10a seed=42
# [grid:holdout] 212/1296 config_id=ad7102c11556 seed=42
# [grid:holdout] 213/1296 config_id=a287d07926fb seed=42
# [grid:holdout] 214/1296 config_id=2536f11565af seed=42
# [grid:holdout] 215/1296 config_id=9a9f1cef6e48 seed=42
# [grid:holdout] 216/1296 config_id=5e655ded30b0 seed=42
# [grid:holdout] 217/1296 config_id=85c63a3c9521 seed=42
# [grid:holdout] 218/1296 config_id=4cc88909abbc seed=42
# [grid:holdout] 219/1296 config_id=6e3e88e8ae7c seed=42
# [grid:holdout] 220/1296 config_id=0bb218f10ec8 seed=42
# [grid:holdout] 221/1296 config_id=6421fac92fef seed=42
# [grid:holdout] 222/1296 config_id=8cb910306f22 seed=42
# [grid:holdout] 223/1296 config_id=3be5ab33f797 seed=42
# [grid:holdout] 224/1296 config_id=5c50d186e081 seed=42
# [grid:holdout] 225/1296 config_id=79956c49b15d seed=42
# [grid:holdout] 226/1296 config_id=b699ea2308c2 seed=42
# [grid:holdout] 227/1296 config_id=14a2bbf7b7b4 seed=42
# [grid:holdout] 228/1296 config_id=bd3c09640d32 seed=42
# [grid:holdout] 229/1296 config_id=7325c03b37d9 seed=42
# [grid:holdout] 230/1296 config_id=33f46ed72329 seed=42
# [grid:holdout] 231/1296 config_id=80fd75aa8bcf seed=42
# [grid:holdout] 232/1296 config_id=8754e4051fc2 seed=42
# [grid:holdout] 233/1296 config_id=8e262a79f0c4 seed=42
# [grid:holdout] 234/1296 config_id=848cac1f7e3e seed=42
# [grid:holdout] 235/1296 config_id=aa18d3939059 seed=42
# [grid:holdout] 236/1296 config_id=35494e23fe51 seed=42
# [grid:holdout] 237/1296 config_id=c470885f8407 seed=42
# [grid:holdout] 238/1296 config_id=4eab9884b0dd seed=42
# [grid:holdout] 239/1296 config_id=f70c7f1a207a seed=42
# [grid:holdout] 240/1296 config_id=89f400df93de seed=42
# [grid:holdout] 241/1296 config_id=173517803d63 seed=42
# [grid:holdout] 242/1296 config_id=91cbf345e343 seed=42
# [grid:holdout] 243/1296 config_id=bd2f2a63d38a seed=42
# [grid:holdout] 244/1296 config_id=3e59f5cc5f51 seed=42
# [grid:holdout] 245/1296 config_id=f89904be1b6e seed=42
# [grid:holdout] 246/1296 config_id=f4b22adf4cae seed=42
# [grid:holdout] 247/1296 config_id=ab069d68fa78 seed=42
# [grid:holdout] 248/1296 config_id=967a3a78c49f seed=42
# [grid:holdout] 249/1296 config_id=b89a870eec25 seed=42
# [grid:holdout] 250/1296 config_id=2585e14e245c seed=42
# [grid:holdout] 251/1296 config_id=95263a5e770c seed=42
# [grid:holdout] 252/1296 config_id=c698ed543261 seed=42
# [grid:holdout] 253/1296 config_id=c4c090883983 seed=42
# [grid:holdout] 254/1296 config_id=912eb8455c32 seed=42
# [grid:holdout] 255/1296 config_id=d40598d3cc51 seed=42
# [grid:holdout] 256/1296 config_id=802aaa2ebce7 seed=42
# [grid:holdout] 257/1296 config_id=59c21348545c seed=42
# [grid:holdout] 258/1296 config_id=e18bc9b75c93 seed=42
# [grid:holdout] 259/1296 config_id=8bda65ec6327 seed=42
# [grid:holdout] 260/1296 config_id=4240eab449fa seed=42
# [grid:holdout] 261/1296 config_id=aac7a896a7fe seed=42
# [grid:holdout] 262/1296 config_id=4c15d03ba220 seed=42
# [grid:holdout] 263/1296 config_id=bf166729d70b seed=42
# [grid:holdout] 264/1296 config_id=6daa6c5dc064 seed=42
# [grid:holdout] 265/1296 config_id=c2ba375d2204 seed=42
# [grid:holdout] 266/1296 config_id=a5f753b253a4 seed=42
# [grid:holdout] 267/1296 config_id=2215add94765 seed=42
# [grid:holdout] 268/1296 config_id=09c324a4f9f0 seed=42
# [grid:holdout] 269/1296 config_id=631ee5c8cee9 seed=42
# [grid:holdout] 270/1296 config_id=ee2c5080be5e seed=42
# [grid:holdout] 271/1296 config_id=6c0c82c44816 seed=42
# [grid:holdout] 272/1296 config_id=a37340c565d8 seed=42
# [grid:holdout] 273/1296 config_id=62ed9e3cff00 seed=42
# [grid:holdout] 274/1296 config_id=856ca9f3650e seed=42
# [grid:holdout] 275/1296 config_id=700aafa6d4d7 seed=42
# [grid:holdout] 276/1296 config_id=40b85ca192fe seed=42
# [grid:holdout] 277/1296 config_id=850c8fe966e0 seed=42
# [grid:holdout] 278/1296 config_id=634d542076f9 seed=42
# [grid:holdout] 279/1296 config_id=d4a43d595bc2 seed=42
# [grid:holdout] 280/1296 config_id=33470a8e21cc seed=42
# [grid:holdout] 281/1296 config_id=1515be0166b6 seed=42
# [grid:holdout] 282/1296 config_id=ffabd1f55a97 seed=42
# [grid:holdout] 283/1296 config_id=30eae1e3f6fc seed=42
# [grid:holdout] 284/1296 config_id=593f17995fa4 seed=42
# [grid:holdout] 285/1296 config_id=0cb68c65d442 seed=42
# [grid:holdout] 286/1296 config_id=3818e5b7fdeb seed=42
# [grid:holdout] 287/1296 config_id=a6879f023b4c seed=42
# [grid:holdout] 288/1296 config_id=5dae3d7201f3 seed=42
# [grid:holdout] 289/1296 config_id=18c5bbf4e899 seed=42
# [grid:holdout] 290/1296 config_id=0ccb2f8ac311 seed=42
# [grid:holdout] 291/1296 config_id=fa23eba9fb87 seed=42
# [grid:holdout] 292/1296 config_id=9422297f3ca0 seed=42
# [grid:holdout] 293/1296 config_id=0d3dbd6d6d15 seed=42
# [grid:holdout] 294/1296 config_id=694619ef6997 seed=42
# [grid:holdout] 295/1296 config_id=148c4a53199a seed=42
# [grid:holdout] 296/1296 config_id=8d6966e26e40 seed=42
# [grid:holdout] 297/1296 config_id=daa3a704c716 seed=42
# [grid:holdout] 298/1296 config_id=13fa1af85484 seed=42
# [grid:holdout] 299/1296 config_id=3830958ddf0f seed=42
# [grid:holdout] 300/1296 config_id=67deafee551c seed=42
# [grid:holdout] 301/1296 config_id=3fcbed19ea61 seed=42
# [grid:holdout] 302/1296 config_id=43743d5476da seed=42
# [grid:holdout] 303/1296 config_id=3fd8d1d17a13 seed=42
# [grid:holdout] 304/1296 config_id=086c1d165014 seed=42
# [grid:holdout] 305/1296 config_id=c65e2d075914 seed=42
# [grid:holdout] 306/1296 config_id=9360d53367f9 seed=42
# [grid:holdout] 307/1296 config_id=9e8cf0376518 seed=42
# [grid:holdout] 308/1296 config_id=4dcc7db22549 seed=42
# [grid:holdout] 309/1296 config_id=116951772d55 seed=42
# [grid:holdout] 310/1296 config_id=76d778849e9f seed=42
# [grid:holdout] 311/1296 config_id=d17bf8171539 seed=42
# [grid:holdout] 312/1296 config_id=7fc21443edc4 seed=42
# [grid:holdout] 313/1296 config_id=3aaddc88a221 seed=42
# [grid:holdout] 314/1296 config_id=efb2c7cf2d3e seed=42
# [grid:holdout] 315/1296 config_id=08771834931f seed=42
# [grid:holdout] 316/1296 config_id=9d9afba21a9c seed=42
# [grid:holdout] 317/1296 config_id=f47e965d3167 seed=42
# [grid:holdout] 318/1296 config_id=f5c9509f9543 seed=42
# [grid:holdout] 319/1296 config_id=56475620d6b3 seed=42
# [grid:holdout] 320/1296 config_id=c1a3b5651e7e seed=42
# [grid:holdout] 321/1296 config_id=30ae654eb087 seed=42
# [grid:holdout] 322/1296 config_id=7cf8b6c29c25 seed=42
# [grid:holdout] 323/1296 config_id=d52d964619c4 seed=42
# [grid:holdout] 324/1296 config_id=fd4cf31a7001 seed=42
# [grid:holdout] 325/1296 config_id=bc42d71660b3 seed=42
# [grid:holdout] 326/1296 config_id=7c3ac134ea9a seed=42
# [grid:holdout] 327/1296 config_id=fbb00f000b2c seed=42
# [grid:holdout] 328/1296 config_id=dc48d4062485 seed=42
# [grid:holdout] 329/1296 config_id=10271d4d0152 seed=42
# [grid:holdout] 330/1296 config_id=ded935b68e96 seed=42
# [grid:holdout] 331/1296 config_id=1e05966bdeb1 seed=42
# [grid:holdout] 332/1296 config_id=3700f258f74e seed=42
# [grid:holdout] 333/1296 config_id=c663ea43904e seed=42
# [grid:holdout] 334/1296 config_id=083765b8c290 seed=42
# [grid:holdout] 335/1296 config_id=61cf0a9c874e seed=42
# [grid:holdout] 336/1296 config_id=1b4d74fd0bc1 seed=42
# [grid:holdout] 337/1296 config_id=48877d1358d5 seed=42
# [grid:holdout] 338/1296 config_id=c779b7d9244a seed=42
# [grid:holdout] 339/1296 config_id=051e215e013b seed=42
# [grid:holdout] 340/1296 config_id=78d636d8faf0 seed=42
# [grid:holdout] 341/1296 config_id=1e9125dd6201 seed=42
# [grid:holdout] 342/1296 config_id=4e5faaaec37a seed=42
# [grid:holdout] 343/1296 config_id=7c1642c271a9 seed=42
# [grid:holdout] 344/1296 config_id=0f2817f68f9c seed=42
# [grid:holdout] 345/1296 config_id=14d971772eb2 seed=42
# [grid:holdout] 346/1296 config_id=474160106b15 seed=42
# [grid:holdout] 347/1296 config_id=05ed26bb63e0 seed=42
# [grid:holdout] 348/1296 config_id=cbcdc0a7c486 seed=42
# [grid:holdout] 349/1296 config_id=9ab6b0c2dee9 seed=42
# [grid:holdout] 350/1296 config_id=a2d0f0097308 seed=42
# [grid:holdout] 351/1296 config_id=9a8221a13b27 seed=42
# [grid:holdout] 352/1296 config_id=0755d2f8bc72 seed=42
# [grid:holdout] 353/1296 config_id=3feb88540316 seed=42
# [grid:holdout] 354/1296 config_id=49a8f420b685 seed=42
# [grid:holdout] 355/1296 config_id=0df326ec535c seed=42
# [grid:holdout] 356/1296 config_id=dbe4f0f76c1e seed=42
# [grid:holdout] 357/1296 config_id=40ad4300d3d1 seed=42
# [grid:holdout] 358/1296 config_id=4c20195eb22f seed=42
# [grid:holdout] 359/1296 config_id=bef5ee3978d4 seed=42
# [grid:holdout] 360/1296 config_id=4556694a1f38 seed=42
# [grid:holdout] 361/1296 config_id=cc0e56b1e59d seed=42
# [grid:holdout] 362/1296 config_id=7abe06c7e2fe seed=42
# [grid:holdout] 363/1296 config_id=77aedf65e139 seed=42
# [grid:holdout] 364/1296 config_id=f5762f6e8144 seed=42
# [grid:holdout] 365/1296 config_id=edc4ded5e048 seed=42
# [grid:holdout] 366/1296 config_id=210718b7f15e seed=42
# [grid:holdout] 367/1296 config_id=5a621298e248 seed=42
# [grid:holdout] 368/1296 config_id=b5b68d04a990 seed=42
# [grid:holdout] 369/1296 config_id=748952d71027 seed=42
# [grid:holdout] 370/1296 config_id=7d2e6e6890ce seed=42
# [grid:holdout] 371/1296 config_id=b3f24ffa7053 seed=42
# [grid:holdout] 372/1296 config_id=0a79574fbb70 seed=42
# [grid:holdout] 373/1296 config_id=ffbe7ee8f52c seed=42
# [grid:holdout] 374/1296 config_id=e9b298623355 seed=42
# [grid:holdout] 375/1296 config_id=0165941f4386 seed=42
# [grid:holdout] 376/1296 config_id=ebce2c4dac4c seed=42
# [grid:holdout] 377/1296 config_id=483c60054796 seed=42
# [grid:holdout] 378/1296 config_id=edd16ece9167 seed=42
# [grid:holdout] 379/1296 config_id=1b4974387813 seed=42
# [grid:holdout] 380/1296 config_id=041351c12dd2 seed=42
# [grid:holdout] 381/1296 config_id=79004193f820 seed=42
# [grid:holdout] 382/1296 config_id=21d436f570eb seed=42
# [grid:holdout] 383/1296 config_id=fd9753eec835 seed=42
# [grid:holdout] 384/1296 config_id=22e3b3363277 seed=42
# [grid:holdout] 385/1296 config_id=3225382ccd2d seed=42
# [grid:holdout] 386/1296 config_id=9352b5d627da seed=42
# [grid:holdout] 387/1296 config_id=b5a82a7db3f2 seed=42
# [grid:holdout] 388/1296 config_id=3fbdba6aa904 seed=42
# [grid:holdout] 389/1296 config_id=3d383c47a8a7 seed=42
# [grid:holdout] 390/1296 config_id=a4f2f9fca738 seed=42
# [grid:holdout] 391/1296 config_id=61d4b8715b17 seed=42
# [grid:holdout] 392/1296 config_id=49716d8b293f seed=42
# [grid:holdout] 393/1296 config_id=fd73a2f6fc7d seed=42
# [grid:holdout] 394/1296 config_id=25e8a747fb8c seed=42
# [grid:holdout] 395/1296 config_id=14c00413cb33 seed=42
# [grid:holdout] 396/1296 config_id=93f601660cd5 seed=42
# [grid:holdout] 397/1296 config_id=6bfc8d832b1a seed=42
# [grid:holdout] 398/1296 config_id=4209852d979e seed=42
# [grid:holdout] 399/1296 config_id=1d36213e2d67 seed=42
# [grid:holdout] 400/1296 config_id=fa702f60e5f6 seed=42
# [grid:holdout] 401/1296 config_id=a25f0dc3a2fe seed=42
# [grid:holdout] 402/1296 config_id=9280cf418dfb seed=42
# [grid:holdout] 403/1296 config_id=75e522362349 seed=42
# [grid:holdout] 404/1296 config_id=110424fa2348 seed=42
# [grid:holdout] 405/1296 config_id=c2df8803f42b seed=42
# [grid:holdout] 406/1296 config_id=b26def70a77b seed=42
# [grid:holdout] 407/1296 config_id=8048c07f1268 seed=42
# [grid:holdout] 408/1296 config_id=9df3e731bc4f seed=42
# [grid:holdout] 409/1296 config_id=331781c12001 seed=42
# [grid:holdout] 410/1296 config_id=a09b1ed5015b seed=42
# [grid:holdout] 411/1296 config_id=85f4ada26299 seed=42
# [grid:holdout] 412/1296 config_id=4c471c6f7d16 seed=42
# [grid:holdout] 413/1296 config_id=d5cb300ab143 seed=42
# [grid:holdout] 414/1296 config_id=d195c65bd0d3 seed=42
# [grid:holdout] 415/1296 config_id=78debcfae3d9 seed=42
# [grid:holdout] 416/1296 config_id=d9fc78fb2c4e seed=42
# [grid:holdout] 417/1296 config_id=00894f008cf9 seed=42
# [grid:holdout] 418/1296 config_id=efd2943d17a2 seed=42
# [grid:holdout] 419/1296 config_id=6e11f67267c4 seed=42
# [grid:holdout] 420/1296 config_id=d0903bd5109d seed=42
# [grid:holdout] 421/1296 config_id=7d3c041b6b05 seed=42
# [grid:holdout] 422/1296 config_id=f8ba0a94a462 seed=42
# [grid:holdout] 423/1296 config_id=8c43afbf0c9d seed=42
# [grid:holdout] 424/1296 config_id=20cfac377e1a seed=42
# [grid:holdout] 425/1296 config_id=88a93133fdac seed=42
# [grid:holdout] 426/1296 config_id=6794cf809d52 seed=42
# [grid:holdout] 427/1296 config_id=1eebd94c6e1a seed=42
# [grid:holdout] 428/1296 config_id=28bcbddbab58 seed=42
# [grid:holdout] 429/1296 config_id=06047c972fad seed=42
# [grid:holdout] 430/1296 config_id=61bd2465069c seed=42
# [grid:holdout] 431/1296 config_id=50dab6a1ee08 seed=42
# [grid:holdout] 432/1296 config_id=9a2ca182ed07 seed=42
# [grid:holdout] 433/1296 config_id=6b41d767df90 seed=42
# [grid:holdout] 434/1296 config_id=fa693b8de3b2 seed=42
# [grid:holdout] 435/1296 config_id=5b33031b8360 seed=42
# [grid:holdout] 436/1296 config_id=3561f5b0afd7 seed=42
# [grid:holdout] 437/1296 config_id=08dac7670aab seed=42
# [grid:holdout] 438/1296 config_id=c34907f7e7dc seed=42
# [grid:holdout] 439/1296 config_id=9a8ef22bc800 seed=42
# [grid:holdout] 440/1296 config_id=1ad8627eb5e6 seed=42
# [grid:holdout] 441/1296 config_id=2588761d7dff seed=42
# [grid:holdout] 442/1296 config_id=3e8e3895ba54 seed=42
# [grid:holdout] 443/1296 config_id=07b0e8231d3d seed=42
# [grid:holdout] 444/1296 config_id=59c811c3cedd seed=42
# [grid:holdout] 445/1296 config_id=5113a64a6ad1 seed=42
# [grid:holdout] 446/1296 config_id=91a137bf45ac seed=42
# [grid:holdout] 447/1296 config_id=fa24876f15cd seed=42
# [grid:holdout] 448/1296 config_id=98b26d7fa8f1 seed=42
# [grid:holdout] 449/1296 config_id=771a4aab0c6b seed=42
# [grid:holdout] 450/1296 config_id=8ff3d3de8607 seed=42
# [grid:holdout] 451/1296 config_id=e78394f2a7cc seed=42
# [grid:holdout] 452/1296 config_id=a254d10ff414 seed=42
# [grid:holdout] 453/1296 config_id=8e48edc1dad2 seed=42
# [grid:holdout] 454/1296 config_id=a4273d9a14e3 seed=42
# [grid:holdout] 455/1296 config_id=529578b42cf7 seed=42
# [grid:holdout] 456/1296 config_id=7f7e2ac90d00 seed=42
# [grid:holdout] 457/1296 config_id=e3d70c013569 seed=42
# [grid:holdout] 458/1296 config_id=aef6fd920fb3 seed=42
# [grid:holdout] 459/1296 config_id=1e4966ec5ab1 seed=42
# [grid:holdout] 460/1296 config_id=8ee7f324c388 seed=42
# [grid:holdout] 461/1296 config_id=186a6347a8f1 seed=42
# [grid:holdout] 462/1296 config_id=5e26b2aa2482 seed=42
# [grid:holdout] 463/1296 config_id=5fd6f0423de1 seed=42
# [grid:holdout] 464/1296 config_id=af6c1477838c seed=42
# [grid:holdout] 465/1296 config_id=b9f58e1f71f0 seed=42
# [grid:holdout] 466/1296 config_id=a0122d3dd5a3 seed=42
# [grid:holdout] 467/1296 config_id=764b1df8ac2d seed=42
# [grid:holdout] 468/1296 config_id=5b8f358ef57d seed=42
# [grid:holdout] 469/1296 config_id=eb3ed8829aae seed=42
# [grid:holdout] 470/1296 config_id=24aa4a474bc7 seed=42
# [grid:holdout] 471/1296 config_id=6ccb1a1ec090 seed=42
# [grid:holdout] 472/1296 config_id=86b1b0ea9659 seed=42
# [grid:holdout] 473/1296 config_id=dfc699d724a2 seed=42
# [grid:holdout] 474/1296 config_id=16d4ecb8e00c seed=42
# [grid:holdout] 475/1296 config_id=e54387d9b35b seed=42
# [grid:holdout] 476/1296 config_id=1cd03b64b00d seed=42
# [grid:holdout] 477/1296 config_id=8ee94787a099 seed=42
# [grid:holdout] 478/1296 config_id=b0cd7da591a8 seed=42
# [grid:holdout] 479/1296 config_id=272fd2a43bc6 seed=42
# [grid:holdout] 480/1296 config_id=2aa02dc27160 seed=42
# [grid:holdout] 481/1296 config_id=bc05ffa430d2 seed=42
# [grid:holdout] 482/1296 config_id=246d88bc035a seed=42
# [grid:holdout] 483/1296 config_id=350a90ad1e1d seed=42
# [grid:holdout] 484/1296 config_id=7ad5a05a326b seed=42
# [grid:holdout] 485/1296 config_id=85c959b8171f seed=42
# [grid:holdout] 486/1296 config_id=070c074e6e11 seed=42
# [grid:holdout] 487/1296 config_id=b2280b473ff3 seed=42
# [grid:holdout] 488/1296 config_id=ef8891e63cc1 seed=42
# [grid:holdout] 489/1296 config_id=4fb6a25ab7ed seed=42
# [grid:holdout] 490/1296 config_id=61d66b2b04ab seed=42
# [grid:holdout] 491/1296 config_id=e15be9e68d13 seed=42
# [grid:holdout] 492/1296 config_id=89eda6bbdacc seed=42
# [grid:holdout] 493/1296 config_id=b0f17de97f13 seed=42
# [grid:holdout] 494/1296 config_id=c54cc4847107 seed=42
# [grid:holdout] 495/1296 config_id=e7d7abb5354c seed=42
# [grid:holdout] 496/1296 config_id=d28a1fbc7a3a seed=42
# [grid:holdout] 497/1296 config_id=187e9d6e7969 seed=42
# [grid:holdout] 498/1296 config_id=4fe29361f325 seed=42
# [grid:holdout] 499/1296 config_id=5d62d7b01ed3 seed=42
# [grid:holdout] 500/1296 config_id=4545599a52d5 seed=42
# [grid:holdout] 501/1296 config_id=124750beb7d4 seed=42
# [grid:holdout] 502/1296 config_id=f05259572f69 seed=42
# [grid:holdout] 503/1296 config_id=ae2a6a390133 seed=42
# [grid:holdout] 504/1296 config_id=1ea73bab6226 seed=42
# [grid:holdout] 505/1296 config_id=6827f43b1b23 seed=42
# [grid:holdout] 506/1296 config_id=e1a95a47cda3 seed=42
# [grid:holdout] 507/1296 config_id=ff76c7047f18 seed=42
# [grid:holdout] 508/1296 config_id=372f8f53923b seed=42
# [grid:holdout] 509/1296 config_id=83f18d60c2a1 seed=42
# [grid:holdout] 510/1296 config_id=16c245d8ffbc seed=42
# [grid:holdout] 511/1296 config_id=943fbfd45cdf seed=42
# [grid:holdout] 512/1296 config_id=5ae620b8eb56 seed=42
# [grid:holdout] 513/1296 config_id=e6b42e1ce286 seed=42
# [grid:holdout] 514/1296 config_id=fa986f83a79f seed=42
# [grid:holdout] 515/1296 config_id=55714617b8f0 seed=42
# [grid:holdout] 516/1296 config_id=302f3637658e seed=42
# [grid:holdout] 517/1296 config_id=db27db0626bd seed=42
# [grid:holdout] 518/1296 config_id=3ebd87e2b59d seed=42
# [grid:holdout] 519/1296 config_id=9c903759786f seed=42
# [grid:holdout] 520/1296 config_id=d7ec34fd2dea seed=42
# [grid:holdout] 521/1296 config_id=6e6fe401e588 seed=42
# [grid:holdout] 522/1296 config_id=ef368b37cdcd seed=42
# [grid:holdout] 523/1296 config_id=6b43c2d09b92 seed=42
# [grid:holdout] 524/1296 config_id=c7ea6a42400f seed=42
# [grid:holdout] 525/1296 config_id=01162ab18875 seed=42
# [grid:holdout] 526/1296 config_id=e762a9b1c8b1 seed=42
# [grid:holdout] 527/1296 config_id=77f5ac988dec seed=42
# [grid:holdout] 528/1296 config_id=0a7d7c8e1bfa seed=42
# [grid:holdout] 529/1296 config_id=7df79c958267 seed=42
# [grid:holdout] 530/1296 config_id=2dc5dfb6103c seed=42
# [grid:holdout] 531/1296 config_id=6b338546cc17 seed=42
# [grid:holdout] 532/1296 config_id=1cccc87f3def seed=42
# [grid:holdout] 533/1296 config_id=4dd4c274ebe8 seed=42
# [grid:holdout] 534/1296 config_id=fbcc934a5310 seed=42
# [grid:holdout] 535/1296 config_id=ab6a64e60baf seed=42
# [grid:holdout] 536/1296 config_id=93a1f1a8bc4d seed=42
# [grid:holdout] 537/1296 config_id=a4e36a264edb seed=42
# [grid:holdout] 538/1296 config_id=8b418618b4af seed=42
# [grid:holdout] 539/1296 config_id=04d1157258b0 seed=42
# [grid:holdout] 540/1296 config_id=b88fb92d9c91 seed=42
# [grid:holdout] 541/1296 config_id=e1be832f29c6 seed=42
# [grid:holdout] 542/1296 config_id=46148c210432 seed=42
# [grid:holdout] 543/1296 config_id=1481bc690d4a seed=42
# [grid:holdout] 544/1296 config_id=ad54f6bc0ac7 seed=42
# [grid:holdout] 545/1296 config_id=f3b6dc62208f seed=42
# [grid:holdout] 546/1296 config_id=b6736b78fefc seed=42
# [grid:holdout] 547/1296 config_id=4194ae4f81f3 seed=42
# [grid:holdout] 548/1296 config_id=4baed748d204 seed=42
# [grid:holdout] 549/1296 config_id=8db55899a00b seed=42
# [grid:holdout] 550/1296 config_id=4bc586f2dcc2 seed=42
# [grid:holdout] 551/1296 config_id=609bd8700c65 seed=42
# [grid:holdout] 552/1296 config_id=2bacd3d9d8c8 seed=42
# [grid:holdout] 553/1296 config_id=a9953fcb68c7 seed=42
# [grid:holdout] 554/1296 config_id=5a4d64ddcf9b seed=42
# [grid:holdout] 555/1296 config_id=666758725a5f seed=42
# [grid:holdout] 556/1296 config_id=4f02d1c35352 seed=42
# [grid:holdout] 557/1296 config_id=530f50c7c412 seed=42
# [grid:holdout] 558/1296 config_id=6ffe06785415 seed=42
# [grid:holdout] 559/1296 config_id=4c9662bef4c0 seed=42
# [grid:holdout] 560/1296 config_id=e228e0aad21e seed=42
# [grid:holdout] 561/1296 config_id=a80e01964478 seed=42
# [grid:holdout] 562/1296 config_id=1a05ea39ffa9 seed=42
# [grid:holdout] 563/1296 config_id=2fdee5f8ce0b seed=42
# [grid:holdout] 564/1296 config_id=bce45cfff19d seed=42
# [grid:holdout] 565/1296 config_id=7d26636877f9 seed=42
# [grid:holdout] 566/1296 config_id=d36389bb866e seed=42
# [grid:holdout] 567/1296 config_id=c0f71194441d seed=42
# [grid:holdout] 568/1296 config_id=5d8825c03ff4 seed=42
# [grid:holdout] 569/1296 config_id=02e80d568ae7 seed=42
# [grid:holdout] 570/1296 config_id=3b0502edb2fb seed=42
# [grid:holdout] 571/1296 config_id=e9b905b614a5 seed=42
# [grid:holdout] 572/1296 config_id=63be82c39e22 seed=42
# [grid:holdout] 573/1296 config_id=6891bfc68635 seed=42
# [grid:holdout] 574/1296 config_id=a193406ed8bc seed=42
# [grid:holdout] 575/1296 config_id=1ca5837542ec seed=42
# [grid:holdout] 576/1296 config_id=ba6dbe38675e seed=42
# [grid:holdout] 577/1296 config_id=5dd13fbbd86a seed=42
# [grid:holdout] 578/1296 config_id=37803d5590b8 seed=42
# [grid:holdout] 579/1296 config_id=7044ee690eb7 seed=42
# [grid:holdout] 580/1296 config_id=92cdc3def2e4 seed=42
# [grid:holdout] 581/1296 config_id=592c1a9892f8 seed=42
# [grid:holdout] 582/1296 config_id=47a9931a6acf seed=42
# [grid:holdout] 583/1296 config_id=15a7888c5c18 seed=42
# [grid:holdout] 584/1296 config_id=b947a42293cd seed=42
# [grid:holdout] 585/1296 config_id=1e99bc35bc75 seed=42
# [grid:holdout] 586/1296 config_id=7cb6109e39d2 seed=42
# [grid:holdout] 587/1296 config_id=29f87be2bfa3 seed=42
# [grid:holdout] 588/1296 config_id=4b27d7061c95 seed=42
# [grid:holdout] 589/1296 config_id=7dc2b286a4b6 seed=42
# [grid:holdout] 590/1296 config_id=ab544b62758e seed=42
# [grid:holdout] 591/1296 config_id=b7dd6795944e seed=42
# [grid:holdout] 592/1296 config_id=69d7a4bca8db seed=42
# [grid:holdout] 593/1296 config_id=2b3e5c1e54f6 seed=42
# [grid:holdout] 594/1296 config_id=6f4b34904e0d seed=42
# [grid:holdout] 595/1296 config_id=cb75d93af72e seed=42
# [grid:holdout] 596/1296 config_id=b13fc0e21463 seed=42
# [grid:holdout] 597/1296 config_id=a577e1eb325b seed=42
# [grid:holdout] 598/1296 config_id=54b78a5d5d25 seed=42
# [grid:holdout] 599/1296 config_id=1c6047bd319b seed=42
# [grid:holdout] 600/1296 config_id=b3fc7ec0a95c seed=42
# [grid:holdout] 601/1296 config_id=3c4d04c2d09c seed=42
# [grid:holdout] 602/1296 config_id=a8f55c7b95ee seed=42
# [grid:holdout] 603/1296 config_id=4f056798342a seed=42
# [grid:holdout] 604/1296 config_id=f2168d8b80fb seed=42
# [grid:holdout] 605/1296 config_id=3ba99bc894c4 seed=42
# [grid:holdout] 606/1296 config_id=dbb65996c918 seed=42
# [grid:holdout] 607/1296 config_id=65cf7e4feaaf seed=42
# [grid:holdout] 608/1296 config_id=2440befd9808 seed=42
# [grid:holdout] 609/1296 config_id=234537b57945 seed=42
# [grid:holdout] 610/1296 config_id=4c8478845a5b seed=42
# [grid:holdout] 611/1296 config_id=4cdc3b7b59d8 seed=42
# [grid:holdout] 612/1296 config_id=0bb643ce963e seed=42
# [grid:holdout] 613/1296 config_id=1b8a42ea2991 seed=42
# [grid:holdout] 614/1296 config_id=2c7cb418adad seed=42
# [grid:holdout] 615/1296 config_id=b8ee72123945 seed=42
# [grid:holdout] 616/1296 config_id=bfe0e15e6a08 seed=42
# [grid:holdout] 617/1296 config_id=5e87c82a4d6e seed=42
# [grid:holdout] 618/1296 config_id=a296efb34777 seed=42
# [grid:holdout] 619/1296 config_id=c72e4e06bc2c seed=42
# [grid:holdout] 620/1296 config_id=ae1bae0df334 seed=42
# [grid:holdout] 621/1296 config_id=3e6cc64b545c seed=42
# [grid:holdout] 622/1296 config_id=f5c69e9af866 seed=42
# [grid:holdout] 623/1296 config_id=504d9c973ba5 seed=42
# [grid:holdout] 624/1296 config_id=07ded17e1fcf seed=42
# [grid:holdout] 625/1296 config_id=359465fc3787 seed=42
# [grid:holdout] 626/1296 config_id=6b0fd7380342 seed=42
# [grid:holdout] 627/1296 config_id=db3693a6764b seed=42
# [grid:holdout] 628/1296 config_id=43e986923602 seed=42
# [grid:holdout] 629/1296 config_id=f43e0f191879 seed=42
# [grid:holdout] 630/1296 config_id=e5664ee9e111 seed=42
# [grid:holdout] 631/1296 config_id=a1e150741d07 seed=42
# [grid:holdout] 632/1296 config_id=9331782f444c seed=42
# [grid:holdout] 633/1296 config_id=455287404f9d seed=42
# [grid:holdout] 634/1296 config_id=f7ad4272bc60 seed=42
# [grid:holdout] 635/1296 config_id=b818cfd10fd6 seed=42
# [grid:holdout] 636/1296 config_id=4604383f8a9a seed=42
# [grid:holdout] 637/1296 config_id=296c69068d9b seed=42
# [grid:holdout] 638/1296 config_id=dc19ec0d84c9 seed=42
# [grid:holdout] 639/1296 config_id=4ea9d83db7dc seed=42
# [grid:holdout] 640/1296 config_id=a39c76ea23f7 seed=42
# [grid:holdout] 641/1296 config_id=44c4112f603a seed=42
# [grid:holdout] 642/1296 config_id=e0e9685f9324 seed=42
# [grid:holdout] 643/1296 config_id=a825f9630ebf seed=42
# [grid:holdout] 644/1296 config_id=85edb45f1333 seed=42
# [grid:holdout] 645/1296 config_id=be49deb8f033 seed=42
# [grid:holdout] 646/1296 config_id=3ff71c110c6e seed=42
# [grid:holdout] 647/1296 config_id=374887dfa6ce seed=42
# [grid:holdout] 648/1296 config_id=17cc8db7ee54 seed=42
# [grid:holdout] 649/1296 config_id=5304516345a0 seed=42
# [grid:holdout] 650/1296 config_id=1adfcbb6fa8e seed=42
# [grid:holdout] 651/1296 config_id=65913f054c52 seed=42
# [grid:holdout] 652/1296 config_id=ed24751f4c61 seed=42
# [grid:holdout] 653/1296 config_id=4ab44a83751f seed=42
# [grid:holdout] 654/1296 config_id=1a78b952e08f seed=42
# [grid:holdout] 655/1296 config_id=d9b103b603e3 seed=42
# [grid:holdout] 656/1296 config_id=4105cb605b01 seed=42
# [grid:holdout] 657/1296 config_id=e353f3c5c1b1 seed=42
# [grid:holdout] 658/1296 config_id=2c216dff7fa8 seed=42
# [grid:holdout] 659/1296 config_id=fa05380de5d2 seed=42
# [grid:holdout] 660/1296 config_id=a4571ae8ca20 seed=42
# [grid:holdout] 661/1296 config_id=33446dbbe041 seed=42
# [grid:holdout] 662/1296 config_id=45666a54241d seed=42
# [grid:holdout] 663/1296 config_id=78091f19e117 seed=42
# [grid:holdout] 664/1296 config_id=7db15af07fcc seed=42
# [grid:holdout] 665/1296 config_id=718d39e34cec seed=42
# [grid:holdout] 666/1296 config_id=d14fbf77668f seed=42
# [grid:holdout] 667/1296 config_id=a9230b25e934 seed=42
# [grid:holdout] 668/1296 config_id=f750ad234cc3 seed=42
# [grid:holdout] 669/1296 config_id=f41d05296f38 seed=42
# [grid:holdout] 670/1296 config_id=2839d3bece95 seed=42
# [grid:holdout] 671/1296 config_id=4325c112b6f0 seed=42
# [grid:holdout] 672/1296 config_id=951697dc4145 seed=42
# [grid:holdout] 673/1296 config_id=580b166217f0 seed=42
# [grid:holdout] 674/1296 config_id=a4dd56aa34fd seed=42
# [grid:holdout] 675/1296 config_id=309ab50f2688 seed=42
# [grid:holdout] 676/1296 config_id=7724bf0036e8 seed=42
# [grid:holdout] 677/1296 config_id=d6fa4f5cb98d seed=42
# [grid:holdout] 678/1296 config_id=642bbcd9e0dc seed=42
# [grid:holdout] 679/1296 config_id=d3c0d53a2431 seed=42
# [grid:holdout] 680/1296 config_id=daccb319d1aa seed=42
# [grid:holdout] 681/1296 config_id=ad118a99f328 seed=42
# [grid:holdout] 682/1296 config_id=15ea59bac3c5 seed=42
# [grid:holdout] 683/1296 config_id=0dffae8ce034 seed=42
# [grid:holdout] 684/1296 config_id=10252d52969f seed=42
# [grid:holdout] 685/1296 config_id=36c738cd51b5 seed=42
# [grid:holdout] 686/1296 config_id=2e0178437ca1 seed=42
# [grid:holdout] 687/1296 config_id=21c49f0257b5 seed=42
# [grid:holdout] 688/1296 config_id=92eb82d25065 seed=42
# [grid:holdout] 689/1296 config_id=40b48673edbb seed=42
# [grid:holdout] 690/1296 config_id=db3f9370b2a7 seed=42
# [grid:holdout] 691/1296 config_id=ac7502f47b31 seed=42
# [grid:holdout] 692/1296 config_id=ad2c7b007b8a seed=42
# [grid:holdout] 693/1296 config_id=18ab34d0ac8b seed=42
# [grid:holdout] 694/1296 config_id=8d8991c5d69e seed=42
# [grid:holdout] 695/1296 config_id=6919e058fb2a seed=42
# [grid:holdout] 696/1296 config_id=db9297546769 seed=42
# [grid:holdout] 697/1296 config_id=18e46081bee6 seed=42
# [grid:holdout] 698/1296 config_id=f505d13cbd0d seed=42
# [grid:holdout] 699/1296 config_id=f989f62065eb seed=42
# [grid:holdout] 700/1296 config_id=a18dcd8f2ee1 seed=42
# [grid:holdout] 701/1296 config_id=16bf37bb26ea seed=42
# [grid:holdout] 702/1296 config_id=c90f2a658acb seed=42
# [grid:holdout] 703/1296 config_id=7be7451dcce7 seed=42
# [grid:holdout] 704/1296 config_id=16879c2e5d32 seed=42
# [grid:holdout] 705/1296 config_id=4d423828c2a3 seed=42
# [grid:holdout] 706/1296 config_id=792f4f499b7f seed=42
# [grid:holdout] 707/1296 config_id=9f421dfe4764 seed=42
# [grid:holdout] 708/1296 config_id=bb3d3d1cc8ff seed=42
# [grid:holdout] 709/1296 config_id=fd32f73feccb seed=42
# [grid:holdout] 710/1296 config_id=8be69585b2d7 seed=42
# [grid:holdout] 711/1296 config_id=20503ce6b274 seed=42
# [grid:holdout] 712/1296 config_id=e609a825b87d seed=42
# [grid:holdout] 713/1296 config_id=ed0d12760972 seed=42
# [grid:holdout] 714/1296 config_id=99b3d550405b seed=42
# [grid:holdout] 715/1296 config_id=2e8b5866aae8 seed=42
# [grid:holdout] 716/1296 config_id=9c24eac7ead2 seed=42
# [grid:holdout] 717/1296 config_id=c101ec32f472 seed=42
# [grid:holdout] 718/1296 config_id=a20cc503bf7d seed=42
# [grid:holdout] 719/1296 config_id=7efca67eaf41 seed=42
# [grid:holdout] 720/1296 config_id=edc23345aa97 seed=42
# [grid:holdout] 721/1296 config_id=13d5531deac1 seed=42
# [grid:holdout] 722/1296 config_id=010af36ae8e3 seed=42
# [grid:holdout] 723/1296 config_id=e8b26ad06bcb seed=42
# [grid:holdout] 724/1296 config_id=2b8eda9974b5 seed=42
# [grid:holdout] 725/1296 config_id=1291d99b823e seed=42
# [grid:holdout] 726/1296 config_id=2a868495cfaa seed=42
# [grid:holdout] 727/1296 config_id=b942aa4e0239 seed=42
# [grid:holdout] 728/1296 config_id=a2d0adfd1fc2 seed=42
# [grid:holdout] 729/1296 config_id=17a9061d49e2 seed=42
# [grid:holdout] 730/1296 config_id=316ce88dd1bf seed=42
# [grid:holdout] 731/1296 config_id=3b2e77c1e53d seed=42
# [grid:holdout] 732/1296 config_id=333e382aca83 seed=42
# [grid:holdout] 733/1296 config_id=d9cdab963785 seed=42
# [grid:holdout] 734/1296 config_id=28c015f9a6ad seed=42
# [grid:holdout] 735/1296 config_id=dc4cdd76e957 seed=42
# [grid:holdout] 736/1296 config_id=542bd153649d seed=42
# [grid:holdout] 737/1296 config_id=d1dc4c7a66e3 seed=42
# [grid:holdout] 738/1296 config_id=fd1e0259bf7b seed=42
# [grid:holdout] 739/1296 config_id=6450ec6b821c seed=42
# [grid:holdout] 740/1296 config_id=66f428aab2bd seed=42
# [grid:holdout] 741/1296 config_id=796160acb332 seed=42
# [grid:holdout] 742/1296 config_id=2b0f4cff9c8b seed=42
# [grid:holdout] 743/1296 config_id=22a769fe994c seed=42
# [grid:holdout] 744/1296 config_id=ec3c248d4f8b seed=42
# [grid:holdout] 745/1296 config_id=da5c6a1b9d96 seed=42
# [grid:holdout] 746/1296 config_id=52069c6b94e7 seed=42
# [grid:holdout] 747/1296 config_id=b7050e9972ae seed=42
# [grid:holdout] 748/1296 config_id=147146508d61 seed=42
# [grid:holdout] 749/1296 config_id=e9e9973cc408 seed=42
# [grid:holdout] 750/1296 config_id=98f7644ad35f seed=42
# [grid:holdout] 751/1296 config_id=891a26fad9a0 seed=42
# [grid:holdout] 752/1296 config_id=7f4f041f5dfd seed=42
# [grid:holdout] 753/1296 config_id=80a8db83c8c6 seed=42
# [grid:holdout] 754/1296 config_id=5ea1e302d639 seed=42
# [grid:holdout] 755/1296 config_id=bf96527e108b seed=42
# [grid:holdout] 756/1296 config_id=59460ae028a5 seed=42
# [grid:holdout] 757/1296 config_id=d742d30119e4 seed=42
# [grid:holdout] 758/1296 config_id=e3807fa5023c seed=42
# [grid:holdout] 759/1296 config_id=ae67181f311b seed=42
# [grid:holdout] 760/1296 config_id=f86358fba366 seed=42
# [grid:holdout] 761/1296 config_id=cfca9e9cc5f7 seed=42
# [grid:holdout] 762/1296 config_id=a126b6f75ca7 seed=42
# [grid:holdout] 763/1296 config_id=8bf014b490db seed=42
# [grid:holdout] 764/1296 config_id=2ca60f93cac9 seed=42
# [grid:holdout] 765/1296 config_id=ceafe754ac88 seed=42
# [grid:holdout] 766/1296 config_id=0548dcaf9aeb seed=42
# [grid:holdout] 767/1296 config_id=d59ce0b761b8 seed=42
# [grid:holdout] 768/1296 config_id=6da228a343a7 seed=42
# [grid:holdout] 769/1296 config_id=ddd45393b6aa seed=42
# [grid:holdout] 770/1296 config_id=780eca461334 seed=42
# [grid:holdout] 771/1296 config_id=ebb5fdcfc188 seed=42
# [grid:holdout] 772/1296 config_id=c05fe0075881 seed=42
# [grid:holdout] 773/1296 config_id=227f8078232b seed=42
# [grid:holdout] 774/1296 config_id=2f3d8fb4b626 seed=42
# [grid:holdout] 775/1296 config_id=6bf710e308ae seed=42
# [grid:holdout] 776/1296 config_id=8997046ffbf2 seed=42
# [grid:holdout] 777/1296 config_id=5685d9eb8143 seed=42
# [grid:holdout] 778/1296 config_id=7a378a7d88fd seed=42
# [grid:holdout] 779/1296 config_id=b060c1c556ba seed=42
# [grid:holdout] 780/1296 config_id=1f2017fcf67d seed=42
# [grid:holdout] 781/1296 config_id=d7b45b48e596 seed=42
# [grid:holdout] 782/1296 config_id=f3d995587c93 seed=42
# [grid:holdout] 783/1296 config_id=6dc893f3a309 seed=42
# [grid:holdout] 784/1296 config_id=d24567a4f384 seed=42
# [grid:holdout] 785/1296 config_id=0a1d3cf82ba3 seed=42
# [grid:holdout] 786/1296 config_id=a750a29f24aa seed=42
# [grid:holdout] 787/1296 config_id=db4697e60ee2 seed=42
# [grid:holdout] 788/1296 config_id=2d3ec558b708 seed=42
# [grid:holdout] 789/1296 config_id=6a1544b10b15 seed=42
# [grid:holdout] 790/1296 config_id=c5b7ba149050 seed=42
# [grid:holdout] 791/1296 config_id=b8a0c4c77d9c seed=42
# [grid:holdout] 792/1296 config_id=09b47b291321 seed=42
# [grid:holdout] 793/1296 config_id=9178873fad77 seed=42
# [grid:holdout] 794/1296 config_id=69a9f74757d0 seed=42
# [grid:holdout] 795/1296 config_id=ddc35f782846 seed=42
# [grid:holdout] 796/1296 config_id=8f1432bb804a seed=42
# [grid:holdout] 797/1296 config_id=300b89f47032 seed=42
# [grid:holdout] 798/1296 config_id=33a9b13b1661 seed=42
# [grid:holdout] 799/1296 config_id=6eab65de81c2 seed=42
# [grid:holdout] 800/1296 config_id=ff679bc0bf50 seed=42
# [grid:holdout] 801/1296 config_id=fa3c3918dd57 seed=42
# [grid:holdout] 802/1296 config_id=875ac1037ff6 seed=42
# [grid:holdout] 803/1296 config_id=5fe7d3966b6e seed=42
# [grid:holdout] 804/1296 config_id=396c835053a2 seed=42
# [grid:holdout] 805/1296 config_id=4876b4b8a5ca seed=42
# [grid:holdout] 806/1296 config_id=4cbd6e401ac4 seed=42
# [grid:holdout] 807/1296 config_id=abf7b1e9394e seed=42
# [grid:holdout] 808/1296 config_id=23089076bac3 seed=42
# [grid:holdout] 809/1296 config_id=8f29bca25b52 seed=42
# [grid:holdout] 810/1296 config_id=60377f1a2fd6 seed=42
# [grid:holdout] 811/1296 config_id=28488d6daeee seed=42
# [grid:holdout] 812/1296 config_id=498a85f98c89 seed=42
# [grid:holdout] 813/1296 config_id=3e85c150f09f seed=42
# [grid:holdout] 814/1296 config_id=4d5eb78ef0a9 seed=42
# [grid:holdout] 815/1296 config_id=e1bef3144886 seed=42
# [grid:holdout] 816/1296 config_id=6fda773ee08c seed=42
# [grid:holdout] 817/1296 config_id=04b03f56e636 seed=42
# [grid:holdout] 818/1296 config_id=1355cbb6a70d seed=42
# [grid:holdout] 819/1296 config_id=a7ad47e134b9 seed=42
# [grid:holdout] 820/1296 config_id=86ae8e9f1ae4 seed=42
# [grid:holdout] 821/1296 config_id=df43c91e5bfc seed=42
# [grid:holdout] 822/1296 config_id=6139bf664633 seed=42
# [grid:holdout] 823/1296 config_id=ae2b3f1ef749 seed=42
# [grid:holdout] 824/1296 config_id=58f1484462dc seed=42
# [grid:holdout] 825/1296 config_id=6bb216d33076 seed=42
# [grid:holdout] 826/1296 config_id=f110f21b6db4 seed=42
# [grid:holdout] 827/1296 config_id=c16fba3b7468 seed=42
# [grid:holdout] 828/1296 config_id=48db3cd3359d seed=42
# [grid:holdout] 829/1296 config_id=02e715e46238 seed=42
# [grid:holdout] 830/1296 config_id=fc713df420ce seed=42
# [grid:holdout] 831/1296 config_id=4a33726d7318 seed=42
# [grid:holdout] 832/1296 config_id=a7d139186d39 seed=42
# [grid:holdout] 833/1296 config_id=d3998cec9f13 seed=42
# [grid:holdout] 834/1296 config_id=95b428662b86 seed=42
# [grid:holdout] 835/1296 config_id=ddd9cd156ae9 seed=42
# [grid:holdout] 836/1296 config_id=7170fc9cd2c7 seed=42
# [grid:holdout] 837/1296 config_id=3788462817d8 seed=42
# [grid:holdout] 838/1296 config_id=67f43abf9cea seed=42
# [grid:holdout] 839/1296 config_id=945a12bb37a3 seed=42
# [grid:holdout] 840/1296 config_id=e09cc389de77 seed=42
# [grid:holdout] 841/1296 config_id=dcccc3ca47d2 seed=42
# [grid:holdout] 842/1296 config_id=f592f712323e seed=42
# [grid:holdout] 843/1296 config_id=a1be435b59b1 seed=42
# [grid:holdout] 844/1296 config_id=c09357d0b342 seed=42
# [grid:holdout] 845/1296 config_id=02e7726dcabf seed=42
# [grid:holdout] 846/1296 config_id=d2568d739e32 seed=42
# [grid:holdout] 847/1296 config_id=650b41ae9f95 seed=42
# [grid:holdout] 848/1296 config_id=50f99469cc11 seed=42
# [grid:holdout] 849/1296 config_id=07b995668579 seed=42
# [grid:holdout] 850/1296 config_id=cbbe7921bfbd seed=42
# [grid:holdout] 851/1296 config_id=c0f11266f442 seed=42
# [grid:holdout] 852/1296 config_id=4a99f76403ff seed=42
# [grid:holdout] 853/1296 config_id=871c31dfff6d seed=42
# [grid:holdout] 854/1296 config_id=9e83470921e0 seed=42
# [grid:holdout] 855/1296 config_id=cb550cfe4b3d seed=42
# [grid:holdout] 856/1296 config_id=046683fedd43 seed=42
# [grid:holdout] 857/1296 config_id=70b3f6bcd72a seed=42
# [grid:holdout] 858/1296 config_id=41a9edb27e3c seed=42
# [grid:holdout] 859/1296 config_id=29734dbab1ce seed=42
# [grid:holdout] 860/1296 config_id=e98155b1ec63 seed=42
# [grid:holdout] 861/1296 config_id=c7f07abc985b seed=42
# [grid:holdout] 862/1296 config_id=973f3b19c5e9 seed=42
# [grid:holdout] 863/1296 config_id=d962f86165c0 seed=42
# [grid:holdout] 864/1296 config_id=dda4fd02f9a0 seed=42
# [grid:holdout] 865/1296 config_id=8742bc983880 seed=42
# [grid:holdout] 866/1296 config_id=106497503b9c seed=42
# [grid:holdout] 867/1296 config_id=48965fb00ca4 seed=42
# [grid:holdout] 868/1296 config_id=c909c1f7aa23 seed=42
# [grid:holdout] 869/1296 config_id=9ab9ff4ef45d seed=42
# [grid:holdout] 870/1296 config_id=4fd07c0627f4 seed=42
# [grid:holdout] 871/1296 config_id=56893fa0d99d seed=42
# [grid:holdout] 872/1296 config_id=8d5329d70341 seed=42
# [grid:holdout] 873/1296 config_id=cefa2d26aaeb seed=42
# ...
# [grid:kfold] 3573/3600 config_id=f1d2e051d2cb seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.2137 ± 0.1472
#   Accuracy    : 0.9474 ± 0.0449
#
# Validation Metrics (mean ± std):
#   loss        : 0.3396 ± 0.2179
#   Accuracy    : 0.8722 ± 0.1186
# ============================================================
# [grid:kfold] 3574/3600 config_id=9524c3759273 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.5229 ± 0.1209
#   Accuracy    : 0.7344 ± 0.1711
#
# Validation Metrics (mean ± std):
#   loss        : 0.5687 ± 0.1277
#   Accuracy    : 0.6692 ± 0.1204
# ============================================================
# [grid:kfold] 3575/3600 config_id=b811f36147fc seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.2387 ± 0.1340
#   Accuracy    : 0.9433 ± 0.0449
#
# Validation Metrics (mean ± std):
#   loss        : 0.3659 ± 0.1899
#   Accuracy    : 0.8560 ± 0.1022
# ============================================================
# [grid:kfold] 3576/3600 config_id=c6053a6b0761 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.3766 ± 0.0871
#   Accuracy    : 0.8870 ± 0.0467
#
# Validation Metrics (mean ± std):
#   loss        : 0.4646 ± 0.1110
#   Accuracy    : 0.7832 ± 0.0876
# ============================================================
# [grid:kfold] 3577/3600 config_id=5c9e939f985c seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.2578 ± 0.1261
#   Accuracy    : 0.9433 ± 0.0449
#
# Validation Metrics (mean ± std):
#   loss        : 0.3841 ± 0.1745
#   Accuracy    : 0.8560 ± 0.1022
# ============================================================
# [grid:kfold] 3578/3600 config_id=ddc49d90c517 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.4770 ± 0.1699
#   Accuracy    : 0.7505 ± 0.2175
#
# Validation Metrics (mean ± std):
#   loss        : 0.5698 ± 0.1275
#   Accuracy    : 0.7098 ± 0.1302
# ============================================================
# [grid:kfold] 3579/3600 config_id=4270cedafc9b seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.2765 ± 0.1170
#   Accuracy    : 0.9313 ± 0.0351
#
# Validation Metrics (mean ± std):
#   loss        : 0.4038 ± 0.1563
#   Accuracy    : 0.8316 ± 0.0835
# ============================================================
# [grid:kfold] 3580/3600 config_id=a1348e50c9f0 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.4894 ± 0.1519
#   Accuracy    : 0.7504 ± 0.1825
#
# Validation Metrics (mean ± std):
#   loss        : 0.5788 ± 0.1140
#   Accuracy    : 0.6773 ± 0.1298
# ============================================================
# [grid:kfold] 3581/3600 config_id=03f830d432ab seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.1859 ± 0.1452
#   Accuracy    : 0.9514 ± 0.0398
#
# Validation Metrics (mean ± std):
#   loss        : 0.3070 ± 0.2324
#   Accuracy    : 0.8643 ± 0.1292
# ============================================================
# [grid:kfold] 3582/3600 config_id=46a4c043b7d9 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.4401 ± 0.1954
#   Accuracy    : 0.7787 ± 0.2029
#
# Validation Metrics (mean ± std):
#   loss        : 0.5480 ± 0.1577
#   Accuracy    : 0.6938 ± 0.1605
# ============================================================
# [grid:kfold] 3583/3600 config_id=157ea5914288 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.1985 ± 0.1432
#   Accuracy    : 0.9474 ± 0.0449
#
# Validation Metrics (mean ± std):
#   loss        : 0.3226 ± 0.2236
#   Accuracy    : 0.8643 ± 0.1292
# ============================================================
# [grid:kfold] 3584/3600 config_id=f8a795824e7b seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.4421 ± 0.1973
#   Accuracy    : 0.7787 ± 0.2029
#
# Validation Metrics (mean ± std):
#   loss        : 0.5457 ± 0.1604
#   Accuracy    : 0.6938 ± 0.1605
# ============================================================
# [grid:kfold] 3585/3600 config_id=95574fa3ffe3 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.2053 ± 0.1429
#   Accuracy    : 0.9474 ± 0.0449
#
# Validation Metrics (mean ± std):
#   loss        : 0.3293 ± 0.2209
#   Accuracy    : 0.8643 ± 0.1292
# ============================================================
# [grid:kfold] 3586/3600 config_id=9b4310494ffe seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.4492 ± 0.1921
#   Accuracy    : 0.7787 ± 0.2029
#
# Validation Metrics (mean ± std):
#   loss        : 0.5511 ± 0.1527
#   Accuracy    : 0.6938 ± 0.1605
# ============================================================
# [grid:kfold] 3587/3600 config_id=8ca0d5b30c53 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.2200 ± 0.1374
#   Accuracy    : 0.9474 ± 0.0449
#
# Validation Metrics (mean ± std):
#   loss        : 0.3397 ± 0.2154
#   Accuracy    : 0.8643 ± 0.1292
# ============================================================
# [grid:kfold] 3588/3600 config_id=8f7c70f7b9d5 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.4598 ± 0.1853
#   Accuracy    : 0.7746 ± 0.2007
#
# Validation Metrics (mean ± std):
#   loss        : 0.5548 ± 0.1477
#   Accuracy    : 0.7017 ± 0.1595
# ============================================================
# [grid:kfold] 3589/3600 config_id=9dd3eceeb66e seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.2364 ± 0.1287
#   Accuracy    : 0.9433 ± 0.0501
#
# Validation Metrics (mean ± std):
#   loss        : 0.3590 ± 0.2031
#   Accuracy    : 0.8643 ± 0.1292
# ============================================================
# [grid:kfold] 3590/3600 config_id=a7771f50c869 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.4680 ± 0.1799
#   Accuracy    : 0.7746 ± 0.2007
#
# Validation Metrics (mean ± std):
#   loss        : 0.5587 ± 0.1426
#   Accuracy    : 0.7017 ± 0.1595
# ============================================================
# [grid:kfold] 3591/3600 config_id=deb9a9423a72 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.2050 ± 0.1388
#   Accuracy    : 0.9193 ± 0.0230
#
# Validation Metrics (mean ± std):
#   loss        : 0.2791 ± 0.2282
#   Accuracy    : 0.8720 ± 0.0993
# ============================================================
# [grid:kfold] 3592/3600 config_id=4eec7297ddbc seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.2125 ± 0.1370
#   Accuracy    : 0.9474 ± 0.0449
#
# Validation Metrics (mean ± std):
#   loss        : 0.3626 ± 0.1871
#   Accuracy    : 0.8479 ± 0.0950
# ============================================================
# [grid:kfold] 3593/3600 config_id=8739c94cdc31 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.2429 ± 0.1278
#   Accuracy    : 0.9071 ± 0.0352
#
# Validation Metrics (mean ± std):
#   loss        : 0.3158 ± 0.2172
#   Accuracy    : 0.8562 ± 0.1209
# ============================================================
# [grid:kfold] 3594/3600 config_id=01209ab09776 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.3331 ± 0.1055
#   Accuracy    : 0.8992 ± 0.0399
#
# Validation Metrics (mean ± std):
#   loss        : 0.4308 ± 0.1393
#   Accuracy    : 0.7991 ± 0.0779
# ============================================================
# [grid:kfold] 3595/3600 config_id=426d1217b5d9 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.2389 ± 0.1413
#   Accuracy    : 0.8990 ± 0.0452
#
# Validation Metrics (mean ± std):
#   loss        : 0.3039 ± 0.2144
#   Accuracy    : 0.8562 ± 0.1209
# ============================================================
# [grid:kfold] 3596/3600 config_id=23e7053ca1e9 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.3422 ± 0.1027
#   Accuracy    : 0.8951 ± 0.0444
#
# Validation Metrics (mean ± std):
#   loss        : 0.4342 ± 0.1358
#   Accuracy    : 0.7991 ± 0.0779
# ============================================================
# [grid:kfold] 3597/3600 config_id=781c161c3b70 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.2471 ± 0.1519
#   Accuracy    : 0.9311 ± 0.0567
#
# Validation Metrics (mean ± std):
#   loss        : 0.3478 ± 0.1919
#   Accuracy    : 0.8641 ± 0.1101
# ============================================================
# [grid:kfold] 3598/3600 config_id=c2bb508b2db1 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.2046 ± 0.1328
#   Accuracy    : 0.9474 ± 0.0449
#
# Validation Metrics (mean ± std):
#   loss        : 0.3329 ± 0.2289
#   Accuracy    : 0.8722 ± 0.1186
# ============================================================
# [grid:kfold] 3599/3600 config_id=f7ee6fd9badd seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.2650 ± 0.1460
#   Accuracy    : 0.9311 ± 0.0567
#
# Validation Metrics (mean ± std):
#   loss        : 0.3586 ± 0.1826
#   Accuracy    : 0.8560 ± 0.1022
# ============================================================
# [grid:kfold] 3600/3600 config_id=1cc052e5edc0 seed=42
#
# Starting 3-Fold Cross Validation
# ============================================================
#
# ============================================================
# K-Fold Cross Validation Summary (3 folds)
# ============================================================
#
# Training Metrics (mean ± std):
#   loss        : 0.2174 ± 0.1245
#   Accuracy    : 0.9474 ± 0.0449
#
# Validation Metrics (mean ± std):
#   loss        : 0.3504 ± 0.2069
#   Accuracy    : 0.8722 ± 0.1186
# ============================================================
# MONK-1 DONE
# Best score: 0.005899610354437048
